# %%
#importing libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv("Dataset_full.csv")
df.head()
# Out:
#    2Grammed_APICalls_#0  2Grammed_APICalls_#1  2Grammed_APICalls_#2  \
# 0                     0                    42                     0
# 1                     2                     0                     0
# 2                     0                    40                     0
# 3                     0                    43                     0
# 4                     2                    43                     0
#
#    2Grammed_APICalls_#3  2Grammed_APICalls_#4  2Grammed_APICalls_#5  \
# 0                     0                     0                     0
# 1                     0                     0                     0
# 2                     0                     0                     0
# 3                     0                     0                     0
# 4                     0                     0                     0
#
#    2Grammed_APICalls_#6  2Grammed_APICalls_#7  2Grammed_APICalls_#8  \
# 0                     0                     0                     0
# 1                     0                     0                     0
# 2                     0                     0                     0
# 3                     0                     0                     0
# 4                     0                     0                     0
#
#    2Grammed_APICalls_#9  ...  min_seg_size_forward  Active_Mean  Active_Std  \
# 0                     0  ...                  1156     15852488      281828
# 1                     0  ...                  1003      5625453      438112
# 2                     0  ...                  1377     17206799      607301
# 3                     0  ...                  1530     20024831      540635
# 4                     0  ...                  1373     17770612      334061
#
#    Active_Max  Active_Min  Idle_Mean  Idle_Std   Idle_Max   Idle_Min  Family
# 0    16119128    15653804  170240589  19488345  186397186  155416258   koler
# 1     6270008     5271904  166045107   8283170  173387076  159763065   koler
# 2    17801215    16789493  246965228  22019770  263938727  230197339   koler
# 3    20464751    19626959  218034819  31463640  242915705  194688432   koler
# 4    18098131    17539051  200495551  20186565  218041946  185179596   koler
#
# [5 rows x 919 columns]

# %%
df.corr()
# Out:
#                       2Grammed_APICalls_#0  2Grammed_APICalls_#1  \
# 2Grammed_APICalls_#0              1.000000              0.065521
# 2Grammed_APICalls_#1              0.065521              1.000000
# 2Grammed_APICalls_#2              0.083743              0.005025
# 2Grammed_APICalls_#3              0.077085              0.002602
# 2Grammed_APICalls_#4              0.058666             -0.007148
# ...                                    ...                   ...
# Active_Min                        0.021466              0.017223
# Idle_Mean                        -0.015376              0.040057
# Idle_Std                          0.012017              0.015749
# Idle_Max                         -0.013049              0.039328
# Idle_Min                         -0.016718              0.040618
#
#                       2Grammed_APICalls_#2  2Grammed_APICalls_#3  \
# 2Grammed_APICalls_#0              0.083743              0.077085
# 2Grammed_APICalls_#1              0.005025              0.002602
# 2Grammed_APICalls_#2              1.000000              0.856461
# 2Grammed_APICalls_#3              0.856461              1.000000
# 2Grammed_APICalls_#4              0.080243              0.313029
# ...                                    ...                   ...
# Active_Min                        0.007959              0.020821
# Idle_Mean                        -0.025613             -0.010644
# Idle_Std                          0.015851              0.019175
# Idle_Max                         -0.023285             -0.008556
# Idle_Min                         -0.027641             -0.012236
#
#                       2Grammed_APICalls_#4  2Grammed_APICalls_#5  \
# 2Grammed_APICalls_#0              0.058666             -0.002212
# 2Grammed_APICalls_#1             -0.007148             -0.006497
# 2Grammed_APICalls_#2              0.080243              0.004122
# 2Grammed_APICalls_#3              0.313029              0.257916
# 2Grammed_APICalls_#4              1.000000              0.959700
# ...                                    ...                   ...
# Active_Min                        0.008041             -0.019434
# Idle_Mean                        -0.071160             -0.084086
# Idle_Std                         -0.031529             -0.058806
# Idle_Max                         -0.069390             -0.083408
# Idle_Min                         -0.072279             -0.083979
#
#                       2Grammed_APICalls_#6  2Grammed_APICalls_#7  \
# 2Grammed_APICalls_#0              0.058248             -0.009575
# 2Grammed_APICalls_#1             -0.007835             -0.007847
# 2Grammed_APICalls_#2              0.080116              0.003240
# 2Grammed_APICalls_#3              0.315017              0.326269
# 2Grammed_APICalls_#4              0.992058              0.886076
# ...                                    ...                   ...
# Active_Min                        0.012991              0.005047
# Idle_Mean                        -0.070248             -0.045832
# Idle_Std                         -0.034795             -0.052629
# Idle_Max                         -0.068702             -0.046712
# Idle_Min                         -0.071087             -0.044299
#
#                       2Grammed_APICalls_#8  2Grammed_APICalls_#9  ...  \
# 2Grammed_APICalls_#0              0.074861              0.077905  ...
# 2Grammed_APICalls_#1              0.002301              0.003184  ...
# 2Grammed_APICalls_#2              0.841144              0.862327  ...
# 2Grammed_APICalls_#3              0.998896              0.997616  ...
# 2Grammed_APICalls_#4              0.351836              0.304293  ...
# ...                                    ...                   ...  ...
# Active_Min                        0.019766              0.017643  ...
# Idle_Mean                        -0.012716             -0.009673  ...
# Idle_Std                          0.017447              0.019667  ...
# Idle_Max                         -0.010619             -0.007641  ...
# Idle_Min                         -0.014289             -0.011270  ...
#
#                       act_data_pkt_fwd  min_seg_size_forward  Active_Mean  \
# 2Grammed_APICalls_#0          0.029124              0.013384     0.027078
# 2Grammed_APICalls_#1          0.233027              0.010061     0.018347
# 2Grammed_APICalls_#2         -0.008275              0.006930     0.006096
# 2Grammed_APICalls_#3          0.029080              0.015522     0.022304
# 2Grammed_APICalls_#4         -0.004999              0.023351     0.000184
# ...                                ...                   ...          ...
# Active_Min                    0.559442              0.022141     0.989825
# Idle_Mean                     0.707165              0.019271     0.683808
# Idle_Std                      0.549727              0.061717     0.718050
# Idle_Max                      0.710101              0.022217     0.697506
# Idle_Min                      0.703871              0.016350     0.669174
#
#                       Active_Std  Active_Max  Active_Min  Idle_Mean  Idle_Std  \
# 2Grammed_APICalls_#0    0.050254    0.031915    0.021466  -0.015376  0.012017
# 2Grammed_APICalls_#1    0.015708    0.018842    0.017223   0.040057  0.015749
# 2Grammed_APICalls_#2   -0.010368    0.002898    0.007959  -0.025613  0.015851
# 2Grammed_APICalls_#3    0.018976    0.023262    0.020821  -0.010644  0.019175
# 2Grammed_APICalls_#4   -0.046824   -0.008725    0.008041  -0.071160 -0.031529
# ...                          ...         ...         ...        ...       ...
# Active_Min              0.365483    0.955008    1.000000   0.676722  0.704331
# Idle_Mean               0.366302    0.674007    0.676722   1.000000  0.733258
# Idle_Std                0.400373    0.714819    0.704331   0.733258  1.000000
# Idle_Max                0.377883    0.688642    0.689276   0.998848  0.764462
# Idle_Min                0.356720    0.658952    0.662771   0.999035  0.702835
#
#                       Idle_Max  Idle_Min
# 2Grammed_APICalls_#0 -0.013049 -0.016718
# 2Grammed_APICalls_#1  0.039328  0.040618
# 2Grammed_APICalls_#2 -0.023285 -0.027641
# 2Grammed_APICalls_#3 -0.008556 -0.012236
# 2Grammed_APICalls_#4 -0.069390 -0.072279
# ...                        ...       ...
# Active_Min            0.689276  0.662771
# Idle_Mean             0.998848  0.999035
# Idle_Std              0.764462  0.702835
# Idle_Max              1.000000  0.995814
# Idle_Min              0.995814  1.000000
#
# [918 rows x 918 columns]

# %%
X = df.drop("Family",axis=1)   #Feature Matrix
y = df["Family"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    df.drop(labels=['Family'], axis=1),
    df['Family'],
    test_size=0.2,
    random_state=0)

# %%
import seaborn as sns
#Using Pearson Correlation
corrmat = X_train.corr()
fig, ax = plt.subplots()
fig.set_size_inches(25,25)
sns.heatmap(corrmat)
# Out:
# <AxesSubplot:>

# %%
corrmat
# Out:
#                       2Grammed_APICalls_#0  2Grammed_APICalls_#1  \
# 2Grammed_APICalls_#0              1.000000              0.048582
# 2Grammed_APICalls_#1              0.048582              1.000000
# 2Grammed_APICalls_#2              0.306618              0.039054
# 2Grammed_APICalls_#3              0.045907             -0.000747
# 2Grammed_APICalls_#4              0.080287             -0.006339
# ...                                    ...                   ...
# Active_Min                        0.031037              0.018301
# Idle_Mean                         0.014170              0.045661
# Idle_Std                          0.026858              0.018730
# Idle_Max                          0.014998              0.044751
# Idle_Min                          0.013297              0.046308
#
#                       2Grammed_APICalls_#2  2Grammed_APICalls_#3  \
# 2Grammed_APICalls_#0              0.306618              0.045907
# 2Grammed_APICalls_#1              0.039054             -0.000747
# 2Grammed_APICalls_#2              1.000000              0.364668
# 2Grammed_APICalls_#3              0.364668              1.000000
# 2Grammed_APICalls_#4              0.195922              0.484916
# ...                                    ...                   ...
# Active_Min                        0.035602              0.024910
# Idle_Mean                         0.031769              0.021466
# Idle_Std                          0.143717              0.019961
# Idle_Max                          0.042044              0.022437
# Idle_Min                          0.023880              0.021128
#
#                       2Grammed_APICalls_#4  2Grammed_APICalls_#5  \
# 2Grammed_APICalls_#0              0.080287              0.001153
# 2Grammed_APICalls_#1             -0.006339             -0.006452
# 2Grammed_APICalls_#2              0.195922              0.178260
# 2Grammed_APICalls_#3              0.484916              0.497423
# 2Grammed_APICalls_#4              1.000000              0.971211
# ...                                    ...                   ...
# Active_Min                        0.006873             -0.021591
# Idle_Mean                        -0.072692             -0.092599
# Idle_Std                         -0.035457             -0.063809
# Idle_Max                         -0.070822             -0.091681
# Idle_Min                         -0.073643             -0.092622
#
#                       2Grammed_APICalls_#6  2Grammed_APICalls_#7  \
# 2Grammed_APICalls_#0              0.080135             -0.007184
# 2Grammed_APICalls_#1             -0.006587             -0.007255
# 2Grammed_APICalls_#2              0.196403              0.180201
# 2Grammed_APICalls_#3              0.490407              0.623724
# 2Grammed_APICalls_#4              0.995918              0.921925
# ...                                    ...                   ...
# Active_Min                        0.008305             -0.005556
# Idle_Mean                        -0.073231             -0.057309
# Idle_Std                         -0.038209             -0.057469
# Idle_Max                         -0.071540             -0.057855
# Idle_Min                         -0.074017             -0.056056
#
#                       2Grammed_APICalls_#8  2Grammed_APICalls_#9  ...  \
# 2Grammed_APICalls_#0              0.041332              0.046391  ...
# 2Grammed_APICalls_#1             -0.001236              0.000314  ...
# 2Grammed_APICalls_#2              0.357749              0.364106  ...
# 2Grammed_APICalls_#3              0.997660              0.993512  ...
# 2Grammed_APICalls_#4              0.536889              0.475558  ...
# ...                                    ...                   ...  ...
# Active_Min                        0.021853              0.022220  ...
# Idle_Mean                         0.015048              0.024864  ...
# Idle_Std                          0.015878              0.021205  ...
# Idle_Max                          0.016078              0.025673  ...
# Idle_Min                          0.014684              0.024583  ...
#
#                       act_data_pkt_fwd  min_seg_size_forward  Active_Mean  \
# 2Grammed_APICalls_#0          0.030996              0.015771     0.029323
# 2Grammed_APICalls_#1          0.252532              0.012250     0.018930
# 2Grammed_APICalls_#2          0.130349              0.021885     0.075139
# 2Grammed_APICalls_#3          0.073043              0.023614     0.032850
# 2Grammed_APICalls_#4         -0.001720              0.018603    -0.000997
# ...                                ...                   ...          ...
# Active_Min                    0.568127              0.022291     0.990316
# Idle_Mean                     0.700213              0.018126     0.704668
# Idle_Std                      0.551708              0.068663     0.734622
# Idle_Max                      0.703059              0.021592     0.717879
# Idle_Min                      0.696822              0.014714     0.690160
#
#                       Active_Std  Active_Max  Active_Min  Idle_Mean  Idle_Std  \
# 2Grammed_APICalls_#0    0.001247    0.024738    0.031037   0.014170  0.026858
# 2Grammed_APICalls_#1    0.012734    0.018865    0.018301   0.045661  0.018730
# 2Grammed_APICalls_#2    0.226634    0.114263    0.035602   0.031769  0.143717
# 2Grammed_APICalls_#3    0.063186    0.042679    0.024910   0.021466  0.019961
# 2Grammed_APICalls_#4   -0.047314   -0.009852    0.006873  -0.072692 -0.035457
# ...                          ...         ...         ...        ...       ...
# Active_Min              0.395304    0.957741    1.000000   0.698123  0.724339
# Idle_Mean               0.385617    0.694393    0.698123   1.000000  0.742872
# Idle_Std                0.398897    0.727648    0.724339   0.742872  1.000000
# Idle_Max                0.395580    0.708269    0.710439   0.998856  0.773492
# Idle_Min                0.377343    0.679710    0.684070   0.999028  0.712778
#
#                       Idle_Max  Idle_Min
# 2Grammed_APICalls_#0  0.014998  0.013297
# 2Grammed_APICalls_#1  0.044751  0.046308
# 2Grammed_APICalls_#2  0.042044  0.023880
# 2Grammed_APICalls_#3  0.022437  0.021128
# 2Grammed_APICalls_#4 -0.070822 -0.073643
# ...                        ...       ...
# Active_Min            0.710439  0.684070
# Idle_Mean             0.998856  0.999028
# Idle_Std              0.773492  0.712778
# Idle_Max              1.000000  0.995813
# Idle_Min              0.995813  1.000000
#
# [918 rows x 918 columns]

# %%
# with the following function we can select highly correlated features // 
## atau fungsi untuk memilih fitur-fitur yang berhubungan erat
# it will remove the first feature that is correlated with anything other feature
# menghapus fitur yang berhubungan dengan semua fitur

def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(X_train, 0.90)
len(set(corr_features))
# Out:
# 452

# %%
corr_features
# Out:
# {'2Grammed_APICalls_#10',
#  '2Grammed_APICalls_#102',
#  '2Grammed_APICalls_#105',
#  '2Grammed_APICalls_#107',
#  '2Grammed_APICalls_#110',
#  '2Grammed_APICalls_#111',
#  '2Grammed_APICalls_#126',
#  '2Grammed_APICalls_#128',
#  '2Grammed_APICalls_#131',
#  '2Grammed_APICalls_#144',
#  '2Grammed_APICalls_#148',
#  '2Grammed_APICalls_#157',
#  '2Grammed_APICalls_#161',
#  '2Grammed_APICalls_#162',
#  '2Grammed_APICalls_#166',
#  '2Grammed_APICalls_#168',
#  '2Grammed_APICalls_#169',
#  '2Grammed_APICalls_#170',
#  '2Grammed_APICalls_#173',
#  '2Grammed_APICalls_#177',
#  '2Grammed_APICalls_#18',
#  '2Grammed_APICalls_#180',
#  '2Grammed_APICalls_#181',
#  '2Grammed_APICalls_#184',
#  '2Grammed_APICalls_#185',
#  '2Grammed_APICalls_#186',
#  '2Grammed_APICalls_#188',
#  '2Grammed_APICalls_#189',
#  '2Grammed_APICalls_#191',
#  '2Grammed_APICalls_#192',
#  '2Grammed_APICalls_#193',
#  '2Grammed_APICalls_#200',
#  '2Grammed_APICalls_#201',
#  '2Grammed_APICalls_#205',
#  '2Grammed_APICalls_#206',
#  '2Grammed_APICalls_#209',
#  '2Grammed_APICalls_#21',
#  '2Grammed_APICalls_#211',
#  '2Grammed_APICalls_#213',
#  '2Grammed_APICalls_#216',
#  '2Grammed_APICalls_#217',
#  '2Grammed_APICalls_#223',
#  '2Grammed_APICalls_#224',
#  '2Grammed_APICalls_#226',
#  '2Grammed_APICalls_#235',
#  '2Grammed_APICalls_#238',
#  '2Grammed_APICalls_#240',
#  '2Grammed_APICalls_#242',
#  '2Grammed_APICalls_#246',
#  '2Grammed_APICalls_#247',
#  '2Grammed_APICalls_#248',
#  '2Grammed_APICalls_#250',
#  '2Grammed_APICalls_#251',
#  '2Grammed_APICalls_#252',
#  '2Grammed_APICalls_#253',
#  '2Grammed_APICalls_#254',
#  '2Grammed_APICalls_#256',
#  '2Grammed_APICalls_#258',
#  '2Grammed_APICalls_#259',
#  '2Grammed_APICalls_#260',
#  '2Grammed_APICalls_#264',
#  '2Grammed_APICalls_#268',
#  '2Grammed_APICalls_#272',
#  '2Grammed_APICalls_#279',
#  '2Grammed_APICalls_#285',
#  '2Grammed_APICalls_#287',
#  '2Grammed_APICalls_#288',
#  '2Grammed_APICalls_#291',
#  '2Grammed_APICalls_#292',
#  '2Grammed_APICalls_#296',
#  '2Grammed_APICalls_#299',
#  '2Grammed_APICalls_#30',
#  '2Grammed_APICalls_#300',
#  '2Grammed_APICalls_#303',
#  '2Grammed_APICalls_#304',
#  '2Grammed_APICalls_#305',
#  '2Grammed_APICalls_#307',
#  '2Grammed_APICalls_#308',
#  '2Grammed_APICalls_#309',
#  '2Grammed_APICalls_#310',
#  '2Grammed_APICalls_#313',
#  '2Grammed_APICalls_#315',
#  '2Grammed_APICalls_#317',
#  '2Grammed_APICalls_#318',
#  '2Grammed_APICalls_#319',
#  '2Grammed_APICalls_#322',
#  '2Grammed_APICalls_#323',
#  '2Grammed_APICalls_#324',
#  '2Grammed_APICalls_#326',
#  '2Grammed_APICalls_#330',
#  '2Grammed_APICalls_#333',
#  '2Grammed_APICalls_#336',
#  '2Grammed_APICalls_#340',
#  '2Grammed_APICalls_#341',
#  '2Grammed_APICalls_#347',
#  '2Grammed_APICalls_#348',
#  '2Grammed_APICalls_#349',
#  '2Grammed_APICalls_#35',
#  '2Grammed_APICalls_#355',
#  '2Grammed_APICalls_#356',
#  '2Grammed_APICalls_#358',
#  '2Grammed_APICalls_#359',
#  '2Grammed_APICalls_#36',
#  '2Grammed_APICalls_#360',
#  '2Grammed_APICalls_#362',
#  '2Grammed_APICalls_#366',
#  '2Grammed_APICalls_#367',
#  '2Grammed_APICalls_#37',
#  '2Grammed_APICalls_#372',
#  '2Grammed_APICalls_#373',
#  '2Grammed_APICalls_#375',
#  '2Grammed_APICalls_#377',
#  '2Grammed_APICalls_#38',
#  '2Grammed_APICalls_#380',
#  '2Grammed_APICalls_#381',
#  '2Grammed_APICalls_#387',
#  '2Grammed_APICalls_#388',
#  '2Grammed_APICalls_#389',
#  '2Grammed_APICalls_#390',
#  '2Grammed_APICalls_#391',
#  '2Grammed_APICalls_#393',
#  '2Grammed_APICalls_#396',
#  '2Grammed_APICalls_#398',
#  '2Grammed_APICalls_#399',
#  '2Grammed_APICalls_#400',
#  '2Grammed_APICalls_#401',
#  '2Grammed_APICalls_#405',
#  '2Grammed_APICalls_#406',
#  '2Grammed_APICalls_#409',
#  '2Grammed_APICalls_#411',
#  '2Grammed_APICalls_#412',
#  '2Grammed_APICalls_#415',
#  '2Grammed_APICalls_#417',
#  '2Grammed_APICalls_#418',
#  '2Grammed_APICalls_#425',
#  '2Grammed_APICalls_#430',
#  '2Grammed_APICalls_#432',
#  '2Grammed_APICalls_#433',
#  '2Grammed_APICalls_#436',
#  '2Grammed_APICalls_#439',
#  '2Grammed_APICalls_#440',
#  '2Grammed_APICalls_#441',
#  '2Grammed_APICalls_#442',
#  '2Grammed_APICalls_#443',
#  '2Grammed_APICalls_#444',
#  '2Grammed_APICalls_#445',
#  '2Grammed_APICalls_#447',
#  '2Grammed_APICalls_#448',
#  '2Grammed_APICalls_#450',
#  '2Grammed_APICalls_#453',
#  '2Grammed_APICalls_#455',
#  '2Grammed_APICalls_#459',
#  '2Grammed_APICalls_#46',
#  '2Grammed_APICalls_#460',
#  '2Grammed_APICalls_#463',
#  '2Grammed_APICalls_#464',
#  '2Grammed_APICalls_#466',
#  '2Grammed_APICalls_#468',
#  '2Grammed_APICalls_#469',
#  '2Grammed_APICalls_#473',
#  '2Grammed_APICalls_#474',
#  '2Grammed_APICalls_#475',
#  '2Grammed_APICalls_#476',
#  '2Grammed_APICalls_#477',
#  '2Grammed_APICalls_#478',
#  '2Grammed_APICalls_#479',
#  '2Grammed_APICalls_#480',
#  '2Grammed_APICalls_#481',
#  '2Grammed_APICalls_#482',
#  '2Grammed_APICalls_#483',
#  '2Grammed_APICalls_#485',
#  '2Grammed_APICalls_#487',
#  '2Grammed_APICalls_#488',
#  '2Grammed_APICalls_#489',
#  '2Grammed_APICalls_#492',
#  '2Grammed_APICalls_#495',
#  '2Grammed_APICalls_#498',
#  '2Grammed_APICalls_#499',
#  '2Grammed_APICalls_#5',
#  '2Grammed_APICalls_#501',
#  '2Grammed_APICalls_#502',
#  '2Grammed_APICalls_#503',
#  '2Grammed_APICalls_#508',
#  '2Grammed_APICalls_#509',
#  '2Grammed_APICalls_#514',
#  '2Grammed_APICalls_#515',
#  '2Grammed_APICalls_#516',
#  '2Grammed_APICalls_#519',
#  '2Grammed_APICalls_#520',
#  '2Grammed_APICalls_#526',
#  '2Grammed_APICalls_#527',
#  '2Grammed_APICalls_#530',
#  '2Grammed_APICalls_#531',
#  '2Grammed_APICalls_#534',
#  '2Grammed_APICalls_#535',
#  '2Grammed_APICalls_#536',
#  '2Grammed_APICalls_#537',
#  '2Grammed_APICalls_#538',
#  '2Grammed_APICalls_#539',
#  '2Grammed_APICalls_#54',
#  '2Grammed_APICalls_#541',
#  '2Grammed_APICalls_#542',
#  '2Grammed_APICalls_#543',
#  '2Grammed_APICalls_#546',
#  '2Grammed_APICalls_#547',
#  '2Grammed_APICalls_#548',
#  '2Grammed_APICalls_#549',
#  '2Grammed_APICalls_#550',
#  '2Grammed_APICalls_#551',
#  '2Grammed_APICalls_#552',
#  '2Grammed_APICalls_#553',
#  '2Grammed_APICalls_#554',
#  '2Grammed_APICalls_#555',
#  '2Grammed_APICalls_#556',
#  '2Grammed_APICalls_#557',
#  '2Grammed_APICalls_#558',
#  '2Grammed_APICalls_#559',
#  '2Grammed_APICalls_#560',
#  '2Grammed_APICalls_#561',
#  '2Grammed_APICalls_#564',
#  '2Grammed_APICalls_#569',
#  '2Grammed_APICalls_#571',
#  '2Grammed_APICalls_#572',
#  '2Grammed_APICalls_#573',
#  '2Grammed_APICalls_#574',
#  '2Grammed_APICalls_#577',
#  '2Grammed_APICalls_#590',
#  '2Grammed_APICalls_#593',
#  '2Grammed_APICalls_#597',
#  '2Grammed_APICalls_#599',
#  '2Grammed_APICalls_#6',
#  '2Grammed_APICalls_#60',
#  '2Grammed_APICalls_#602',
#  '2Grammed_APICalls_#603',
#  '2Grammed_APICalls_#604',
#  '2Grammed_APICalls_#606',
#  '2Grammed_APICalls_#607',
#  '2Grammed_APICalls_#608',
#  '2Grammed_APICalls_#61',
#  '2Grammed_APICalls_#613',
#  '2Grammed_APICalls_#614',
#  '2Grammed_APICalls_#615',
#  '2Grammed_APICalls_#616',
#  '2Grammed_APICalls_#618',
#  '2Grammed_APICalls_#62',
#  '2Grammed_APICalls_#620',
#  '2Grammed_APICalls_#621',
#  '2Grammed_APICalls_#622',
#  '2Grammed_APICalls_#623',
#  '2Grammed_APICalls_#624',
#  '2Grammed_APICalls_#626',
#  '2Grammed_APICalls_#628',
#  '2Grammed_APICalls_#63',
#  '2Grammed_APICalls_#630',
#  '2Grammed_APICalls_#632',
#  '2Grammed_APICalls_#633',
#  '2Grammed_APICalls_#639',
#  '2Grammed_APICalls_#640',
#  '2Grammed_APICalls_#641',
#  '2Grammed_APICalls_#655',
#  '2Grammed_APICalls_#656',
#  '2Grammed_APICalls_#657',
#  '2Grammed_APICalls_#661',
#  '2Grammed_APICalls_#662',
#  '2Grammed_APICalls_#665',
#  '2Grammed_APICalls_#666',
#  '2Grammed_APICalls_#669',
#  '2Grammed_APICalls_#670',
#  '2Grammed_APICalls_#672',
#  '2Grammed_APICalls_#673',
#  '2Grammed_APICalls_#674',
#  '2Grammed_APICalls_#675',
#  '2Grammed_APICalls_#676',
#  '2Grammed_APICalls_#677',
#  '2Grammed_APICalls_#678',
#  '2Grammed_APICalls_#680',
#  '2Grammed_APICalls_#681',
#  '2Grammed_APICalls_#682',
#  '2Grammed_APICalls_#683',
#  '2Grammed_APICalls_#684',
#  '2Grammed_APICalls_#685',
#  '2Grammed_APICalls_#686',
#  '2Grammed_APICalls_#688',
#  '2Grammed_APICalls_#689',
#  '2Grammed_APICalls_#692',
#  '2Grammed_APICalls_#693',
#  '2Grammed_APICalls_#694',
#  '2Grammed_APICalls_#695',
#  '2Grammed_APICalls_#698',
#  '2Grammed_APICalls_#699',
#  '2Grammed_APICalls_#7',
#  '2Grammed_APICalls_#70',
#  '2Grammed_APICalls_#700',
#  '2Grammed_APICalls_#701',
#  '2Grammed_APICalls_#703',
#  '2Grammed_APICalls_#704',
#  '2Grammed_APICalls_#705',
#  '2Grammed_APICalls_#707',
#  '2Grammed_APICalls_#708',
#  '2Grammed_APICalls_#709',
#  '2Grammed_APICalls_#711',
#  '2Grammed_APICalls_#712',
#  '2Grammed_APICalls_#713',
#  '2Grammed_APICalls_#714',
#  '2Grammed_APICalls_#715',
#  '2Grammed_APICalls_#716',
#  '2Grammed_APICalls_#717',
#  '2Grammed_APICalls_#719',
#  '2Grammed_APICalls_#720',
#  '2Grammed_APICalls_#721',
#  '2Grammed_APICalls_#722',
#  '2Grammed_APICalls_#723',
#  '2Grammed_APICalls_#724',
#  '2Grammed_APICalls_#725',
#  '2Grammed_APICalls_#726',
#  '2Grammed_APICalls_#727',
#  '2Grammed_APICalls_#728',
#  '2Grammed_APICalls_#729',
#  '2Grammed_APICalls_#730',
#  '2Grammed_APICalls_#731',
#  '2Grammed_APICalls_#732',
#  '2Grammed_APICalls_#733',
#  '2Grammed_APICalls_#734',
#  '2Grammed_APICalls_#735',
#  '2Grammed_APICalls_#736',
#  '2Grammed_APICalls_#737',
#  '2Grammed_APICalls_#739',
#  '2Grammed_APICalls_#740',
#  '2Grammed_APICalls_#741',
#  '2Grammed_APICalls_#742',
#  '2Grammed_APICalls_#743',
#  '2Grammed_APICalls_#744',
#  '2Grammed_APICalls_#749',
#  '2Grammed_APICalls_#752',
#  '2Grammed_APICalls_#753',
#  '2Grammed_APICalls_#754',
#  '2Grammed_APICalls_#755',
#  '2Grammed_APICalls_#756',
#  '2Grammed_APICalls_#757',
#  '2Grammed_APICalls_#758',
#  '2Grammed_APICalls_#759',
#  '2Grammed_APICalls_#760',
#  '2Grammed_APICalls_#762',
#  '2Grammed_APICalls_#763',
#  '2Grammed_APICalls_#764',
#  '2Grammed_APICalls_#765',
#  '2Grammed_APICalls_#766',
#  '2Grammed_APICalls_#768',
#  '2Grammed_APICalls_#770',
#  '2Grammed_APICalls_#783',
#  '2Grammed_APICalls_#784',
#  '2Grammed_APICalls_#789',
#  '2Grammed_APICalls_#790',
#  '2Grammed_APICalls_#792',
#  '2Grammed_APICalls_#793',
#  '2Grammed_APICalls_#794',
#  '2Grammed_APICalls_#796',
#  '2Grammed_APICalls_#797',
#  '2Grammed_APICalls_#799',
#  '2Grammed_APICalls_#8',
#  '2Grammed_APICalls_#801',
#  '2Grammed_APICalls_#802',
#  '2Grammed_APICalls_#803',
#  '2Grammed_APICalls_#804',
#  '2Grammed_APICalls_#805',
#  '2Grammed_APICalls_#806',
#  '2Grammed_APICalls_#807',
#  '2Grammed_APICalls_#808',
#  '2Grammed_APICalls_#809',
#  '2Grammed_APICalls_#81',
#  '2Grammed_APICalls_#810',
#  '2Grammed_APICalls_#811',
#  '2Grammed_APICalls_#812',
#  '2Grammed_APICalls_#813',
#  '2Grammed_APICalls_#814',
#  '2Grammed_APICalls_#815',
#  '2Grammed_APICalls_#816',
#  '2Grammed_APICalls_#817',
#  '2Grammed_APICalls_#818',
#  '2Grammed_APICalls_#819',
#  '2Grammed_APICalls_#820',
#  '2Grammed_APICalls_#821',
#  '2Grammed_APICalls_#822',
#  '2Grammed_APICalls_#823',
#  '2Grammed_APICalls_#824',
#  '2Grammed_APICalls_#825',
#  '2Grammed_APICalls_#826',
#  '2Grammed_APICalls_#829',
#  '2Grammed_APICalls_#830',
#  '2Grammed_APICalls_#834',
#  '2Grammed_APICalls_#835',
#  '2Grammed_APICalls_#836',
#  '2Grammed_APICalls_#837',
#  '2Grammed_APICalls_#839',
#  '2Grammed_APICalls_#84',
#  '2Grammed_APICalls_#840',
#  '2Grammed_APICalls_#88',
#  '2Grammed_APICalls_#9',
#  '2Grammed_APICalls_#90',
#  '2Grammed_APICalls_#94',
#  '2Grammed_APICalls_#95',
#  '2Grammed_APICalls_#97',
#  '2Grammed_APICalls_#98',
#  'ACK_Flag_Count',
#  'Active_Max',
#  'Active_Min',
#  'Average_Packet_Size',
#  'Avg_Bwd_Segment_Size',
#  'Avg_Fwd_Segment_Size',
#  'Bwd_Header_Length',
#  'Bwd_IAT_Max',
#  'Bwd_IAT_Mean',
#  'Bwd_IAT_Min',
#  'Bwd_IAT_Std',
#  'Bwd_IAT_Total',
#  'Bwd_Packet_Length_Max',
#  'Bwd_Packet_Length_Mean',
#  'Bwd_Packet_Length_Min',
#  'Bwd_Packet_Length_Std',
#  'Down/Up_Ratio',
#  'Flow_IAT_Max',
#  'Flow_IAT_Mean',
#  'Flow_IAT_Min',
#  'Flow_IAT_Std',
#  'Fwd_Header_Length2',
#  'Fwd_IAT_Max',
#  'Fwd_IAT_Mean',
#  'Fwd_IAT_Min',
#  'Fwd_IAT_Std',
#  'Fwd_IAT_Total',
#  'Fwd_Packet_Length_Max',
#  'Fwd_Packet_Length_Mean',
#  'Fwd_Packet_Length_Std',
#  'Fwd_Packets/s',
#  'Idle_Max',
#  'Idle_Mean',
#  'Idle_Min',
#  'Init_Win_bytes_backward',
#  'Init_Win_bytes_forward',
#  'Max_Packet_Length',
#  'Min_Packet_Length',
#  'PSH_Flag_Count',
#  'Packet_Length_Mean',
#  'Packet_Length_Std',
#  'Packet_Length_Variance',
#  'SYN_Flag_Count',
#  'Subflow_Bwd_Bytes',
#  'Subflow_Bwd_Packets',
#  'Subflow_Fwd_Bytes',
#  'Subflow_Fwd_Packets',
#  'Total_Length_of_Bwd_Packets',
#  'URG_Flag_Count'}

# %%
X_train.drop(corr_features,axis=1)
# Out:
#      2Grammed_APICalls_#0  2Grammed_APICalls_#1  2Grammed_APICalls_#2  \
# 126                     0                     0                     0
# 66                     11                    54                     0
# 101                     0                     1                     0
# 175                     0                     0                     0
# 246                     0                     0                     0
# ..                    ...                   ...                   ...
# 251                     0                     0                     0
# 192                     0                     0                     0
# 117                     0                     0                     0
# 47                      1                     1                     0
# 172                     0                     0                     0
#
#      2Grammed_APICalls_#3  2Grammed_APICalls_#4  2Grammed_APICalls_#11  \
# 126                     0                     0                      0
# 66                      3                     1                      0
# 101                     0                     0                      0
# 175                     0                     0                      0
# 246                     0                     0                      0
# ..                    ...                   ...                    ...
# 251                     0                     0                      0
# 192                     0                     0                      0
# 117                     0                     0                      0
# 47                    255                     0                      7
# 172                     0                     0                      0
#
#      2Grammed_APICalls_#12  2Grammed_APICalls_#13  2Grammed_APICalls_#14  \
# 126                      0                      0                      0
# 66                       4                      6                      5
# 101                      0                      0                      0
# 175                      0                      0                      0
# 246                      0                      0                      0
# ..                     ...                    ...                    ...
# 251                      0                      0                      0
# 192                      0                      0                      0
# 117                      2                      3                      0
# 47                      15                     22                     47
# 172                      0                      0                      0
#
#      2Grammed_APICalls_#15  ...  Fwd_Avg_Packets/Bulk  Fwd_Avg_Bulk_Rate  \
# 126                      0  ...                     0                  0
# 66                       0  ...                     0                  0
# 101                      0  ...                     0                  0
# 175                      0  ...                     0                  0
# 246                      0  ...                     0                  0
# ..                     ...  ...                   ...                ...
# 251                      0  ...                     0                  0
# 192                      0  ...                     0                  0
# 117                      0  ...                     0                  0
# 47                       1  ...                     0                  0
# 172                      0  ...                     0                  0
#
#      Bwd_Avg_Bytes/Bulk  Bwd_Avg_Packets/Bulk  Bwd_Avg_Bulk_Rate  \
# 126                   0                     0                  0
# 66                    0                     0                  0
# 101                   0                     0                  0
# 175                   0                     0                  0
# 246                   0                     0                  0
# ..                  ...                   ...                ...
# 251                   0                     0                  0
# 192                   0                     0                  0
# 117                   0                     0                  0
# 47                    0                     0                  0
# 172                   0                     0                  0
#
#      act_data_pkt_fwd  min_seg_size_forward  Active_Mean  Active_Std  Idle_Std
# 126                16                   398       968634      333038   4805411
# 66                 47                  1344     13359358      582988  10627216
# 101                58                  1377      6252466      860829  15233722
# 175                54                  1052      6776217     1053618  15353830
# 246                56                  1127      7149580     1017012  12498758
# ..                ...                   ...          ...         ...       ...
# 251                62               2007147      3956263      761096  11365095
# 192               107                  2167     14451858     2416412  31552614
# 117                78             -16411282      8215607      748596  11106041
# 47                 93                  1666      8489860     1221456  13468405
# 172                18                   378      1574759      233752   3691379
#
# [244 rows x 466 columns]

# %%
X_test.drop(corr_features,axis=1)
# Out:
#      2Grammed_APICalls_#0  2Grammed_APICalls_#1  2Grammed_APICalls_#2  \
# 60                     15                   276                     0
# 52                      0                     0                     0
# 59                      0                     0                     0
# 136                     0                     0                     0
# 300                     0                     2                     0
# ..                    ...                   ...                   ...
# 7                       0                     0                     0
# 45                      0                     0                     0
# 200                     0                     0                     0
# 187                    13                    58                     4
# 241                     1                     1                     0
#
#      2Grammed_APICalls_#3  2Grammed_APICalls_#4  2Grammed_APICalls_#11  \
# 60                      1                     0                      0
# 52                      8                     2                      0
# 59                      0                     0                      0
# 136                     0                     0                      0
# 300                     0                     0                      0
# ..                    ...                   ...                    ...
# 7                       0                     0                      0
# 45                      0                     0                      0
# 200                     0                     0                      0
# 187                   212                     0                      1
# 241                    17                     0                      0
#
#      2Grammed_APICalls_#12  2Grammed_APICalls_#13  2Grammed_APICalls_#14  \
# 60                       0                      0                     45
# 52                       0                      0                     70
# 59                       0                      1                      1
# 136                      0                      0                      0
# 300                      0                      0                      0
# ..                     ...                    ...                    ...
# 7                        0                      0                      0
# 45                    1597                   1598                      0
# 200                      0                      0                      0
# 187                      3                      9                     25
# 241                      0                      1                      2
#
#      2Grammed_APICalls_#15  ...  Fwd_Avg_Packets/Bulk  Fwd_Avg_Bulk_Rate  \
# 60                       0  ...                     0                  0
# 52                       0  ...                     0                  0
# 59                       0  ...                     0                  0
# 136                      0  ...                     0                  0
# 300                      0  ...                     0                  0
# ..                     ...  ...                   ...                ...
# 7                        0  ...                     0                  0
# 45                       0  ...                     0                  0
# 200                      0  ...                     0                  0
# 187                      3  ...                     0                  0
# 241                      0  ...                     0                  0
#
#      Bwd_Avg_Bytes/Bulk  Bwd_Avg_Packets/Bulk  Bwd_Avg_Bulk_Rate  \
# 60                    0                     0                  0
# 52                    0                     0                  0
# 59                    0                     0                  0
# 136                   0                     0                  0
# 300                   0                     0                  0
# ..                  ...                   ...                ...
# 7                     0                     0                  0
# 45                    0                     0                  0
# 200                   0                     0                  0
# 187                   0                     0                  0
# 241                   0                     0                  0
#
#      act_data_pkt_fwd  min_seg_size_forward  Active_Mean  Active_Std  Idle_Std
# 60                 13                   187      1986596      911887   6530720
# 52                106               4013477      8681014     1048305  10030947
# 59                 30                   634      3751078      722493  13128884
# 136                15                   241       940802      296289   2757059
# 300                11                   193      4246991      187950   9253128
# ..                ...                   ...          ...         ...       ...
# 7                  92                  1462      6704967      984013  21655290
# 45                 49                   956      6943237      684550  10418358
# 200                72                  1055      7821832     1978557  14489606
# 187               104                  1266     10346463     3168562  22090979
# 241                59                  1409      8682826     1400402  14083964
#
# [61 rows x 466 columns]
